# %% [markdown]
# # Машинное обучение, ВМК МГУ
#
# ## Практическое задание 4. Разложение ошибки на смещение и разброс. Градиентный бустинг ~~своими руками~~
#
# ### Общая информация
#
# Дата выдачи: 27.11.2023
#
# Мягкий дедлайн: 23:59MSK 11.12.2023
#
# Жесткий дедлайн: 23:59MSK 18.12.2023
#
# ### Оценивание и штрафы
# Каждая из задач имеет определенную «стоимость» (указана в скобках около задачи). Максимально допустимая оценка за работу — **10 баллов + 1.5 бонусов**. Проверяющий имеет право снизить оценку за неэффективную реализацию или неопрятные графики.
#
# **Обратите внимание**, что в каждом разделе домашнего задания есть оцениваниемые задачи и есть вопросы. Вопросы дополняют задачи и направлены на то, чтобы проинтерпретировать или обосновать происходящее. Код без интерпретации не имеет смысла, поэтому отвечать на вопросы обязательно — за отсутствие ответов мы будем снижать баллы за задачи. Если вы ответите на вопросы, но не напишете корректный код к соответствующим оцениваемым задачам, то баллы за такое выставлены не будут.
#
# Сдавать задание после указанного срока сдачи нельзя. При выставлении неполного балла за задание в связи с наличием ошибок на усмотрение проверяющего предусмотрена возможность исправить работу на указанных в ответном письме условиях.
#
# Задание выполняется самостоятельно. «Похожие» решения считаются плагиатом и все задействованные студенты (в том числе те, у кого списали) не могут получить за него больше 0 баллов (подробнее о плагиате см. на странице курса). Если вы нашли решение какого-то из заданий (или его часть) в открытом источнике, необходимо указать ссылку на этот источник в отдельном блоке в конце вашей работы (скорее всего вы будете не единственным, кто это нашел, поэтому чтобы исключить подозрение в плагиате, необходима ссылка на источник).
#
# Неэффективная реализация кода может негативно отразиться на оценке.
#
# <p style="color:#de3815;font-size:25px;">
# Напоминание об оформлении и выполнении ноутбука
# </p>
#
# * Все строчки должны быть выполнены. Нужно, чтобы output команды можно было увидеть, не запуская ячейки (кроме редких случаев, когда необходимо намеренно скрыть ненужный output, про такие случаи желательно писать пояснения в тексте). **В противном случае -1 балл**
# * При оформлении ДЗ нужно пользоваться данным файлом в качестве шаблона. **Не нужно** удалять и видоизменять написанный код и текст, если явно не указана такая возможность. Создавать новые ячейки с кодом/текстов там, где это осмысленно и вы считаете необходимым, конечно, можно. **В противном случае -1 балл**
# * В anytask обязательно нужно прикреплять отдельно файл с расширением ipynb (не в архиве, а именно отдельно). Если необходимо отправить еще какие-то файлы, то вынесите их в отдельный архив (если файлов много) и пришлите. **В противном случае -0.5 балла**
# ---
# * Пишите, пожалуйста, выводы и ответы на вопросы в текстовых ячейках/при помощи print в коде/как результат вывода ячейки. При их отсутствии мы не можем понять, сделали ли вы задание и понимаете, что происходит, и **поэтому будем снижать баллы**
# * Если алгоритм не сказано реализовывать явно, его всегда можно импортировать из библиотеки.
# ---
# * Про графики. _Штрафы будут применяться к каждому результату команды отображения графика (plt.show() и др. аналогичные). Исключением являются графики, генерируемые функциями каких-либо сторонних библиотек, если их нельзя кастомизировать_
#
#     * должно быть название (plt.title) графика; **В противном случае &ndash; -0.05 балла**
#     * на графиках должны быть подписаны оси (plt.xlabel, plt.ylabel); **В противном случае &ndash; -0.025 балла за каждую ось**
#     * должны быть подписаны единицы измерения (если это возможно); **В противном случае &ndash; -0.025 балла за каждую ось**
#     * все названия должны быть понятны любому человеку, знакомому с терминологией, без заглядывания в код; **В противном случае &ndash; -0.05 балла**
#     * подписи тиков на осях не должны сливаться как на одной оси, так и между ними; **В противном случае &ndash; -0.025 балла за каждую ось**
#     * если изображено несколько сущностей на одном холсте (например несколько функций), то необходима поясняющая легенда (plt.legend); **В противном случае &ndash; -0.05 балла**
#     * все линии на графиках должны быть чётко видны (нет похожих цветов или цветов, сливающихся с фоном); **В противном случае &ndash; -0.05 балла**
#     * если отображена величина, имеющая очевидный диапазон значений (например, проценты могут быть от 0 до 100), то желательно масштабировать ось на весь диапазон значений (исключением является случай, когда вам необходимо показать малое отличие, которое незаметно в таких масштабах);
#     * графики должны быть не супер-микро и не супер-макро по размерам, так, чтобы можно было увидеть все, что нужно.
#     * при необходимости улучшения наглядности графиков, можно пользоваться логарифмической шкалой по осям x/y.
#
# ### А также..
#
# * Для удобства поиска вопросов, на которые от вас просят ответа, мы пометили их знаком **(?)**
# * Знак **(!)** означает, что выполнение замечания необходимо для **возможности получения полного балла**
# * Даем до +0.3 баллов за выдающиеся успехи по субъективному мнению проверяющих. Этот **бонус** не апеллируется
#
# ### О задании
#
# В этом задании вам предстоит воспользоваться возможностями bootstraping для оценки смещения и разброса алгоритмов машинного обучения. Делать мы это будем на данных boston.
# Также в задании вам будет предложено пообучать готовые модели градиентного бустинга и CatBoost.

# %% [markdown]
# **Напоминание:**
#
# * Все ваши графики должны быть **"красивыми"** --- подробнее о том, как их оформлять, можно найти в первом практическом задании. При несоответствии какиму-то из критериев вам могут снять баллы.
# * Пишите в текстовых ячейках/print в коде ответы на **все вопросы из заданий/просьбы сделать выводы** --- при их отсутствии мы не можем понять, сделали ли вы задание и понимаете, что происходит, и поэтому будем снижать баллы

# %% [markdown]
# ## Часть 1. Bias-Variance Decomposition

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
#from sklearn.datasets import load_boston

# %%
data_url = "http://lib.stat.cmu.edu/datasets/boston"
raw_df = pd.read_csv(data_url, sep="\s+", skiprows=22, header=None)
data = np.hstack([raw_df.values[::2, :], raw_df.values[1::2, :2]])
target = raw_df.values[1::2, 2]

# %%
#boston = load_boston()

# %%
#X = boston["data"]
#y = boston["target"]
X = data
y = target

# %%
X.shape, y.shape
# Out:
# ((506, 13), (506,))

# %% [markdown]
# __Задание 0. (1. балл)__
#
# Сначала разберемся с теорией, для чего решим упрощенную задачу. Пусть мы имеем некоторую выборку $D={Y_1,Y_2,...,Y_k}$. Мы хотим построить константный алгоритм предсказания новых объектов из этой выборки таким образом чтобы он минимизировал функционал $L(c) = \frac{1}{k}\sum_{i=1}^{k}(Y_i - c)^2 + λc^2$, где $λ$ - некоторый известный коэффициент регулягизации.
#
# Найдите оптимальную константу и оцените смещение и разброс такой оценки, если известно что выборка $D$ семплировалась из распределения Стьюдента с параметром n=8.

# %% [markdown]
# 1) $L^\prime(c)=\frac{2}{k}\sum^k_{i=1}{(с - Y_i)} + 2\lambda c = 0 = \frac{1}{k}\sum^k_{i=1}{(с - Y_i)} + \lambda c$
#
# $ \frac{1}{k}\sum^k_{i=1}{Y_i} = с + \lambda c;  c = \frac{1}{(1 + \lambda)k}\sum^k_{i=1}{Y_i}$
#
# 2) Смещение.
# $\mathbb{E}Y_i=0, Y_i \sim St(8)$
# $\mathbb{E}_{x}\bigl[(\mathbb{E}_{X}[\mu(X)(x)] - \mathbb{E}[y|x] )^2\bigr] = \mathbb{E}_{x}\bigl[(\mathbb{E}_{X}[\frac{1}{(1+\lambda)k}\sum^k_{i=1}{Y_i}] -\mathbb{E} y )^2\bigr] = \mathbb{E}_{x}\bigl[(\frac{1}{(1+\lambda)k}\sum^k_{i=1}{\mathbb{E}Y_i} - \mathbb{E}y )^2\bigr] = \mathbb{E}_{x}(0) = 0$
#
# 3) Разброс. $\mathbb{D}(Y) = \mathbb{E}(Y^2) - (\mathbb{E}(Y))^2; \mathbb{E}Y_1 = 0$
#
#  $\mathbb{E}_{x}\bigl[\mathbb{E}_{X}\bigl[(\mu(X)(x) - \mathbb{E}_{X}[\mu(X)(x)] )^2\bigr]\bigr] = \mathbb{E}_{X}(\frac{1}{(1+\lambda)k}\sum^k_{i=1}{Y_i})^2 = \frac{1}{(1+\lambda)^2k}\mathbb{E}Y_1^2 = \frac{1}{(1+\lambda)^2k}*\frac{8}{8 - 2} = \frac{4}{3k(1+\lambda)^2}$

# %% [markdown]
# В реальных задачах мы, конечно же, не знаем распределение на парах объект - правильный ответ. Однако у нас есть набор семплов из этого распределения (обучающую выборка), и мы можем использовать его, чтобы оценивать математические ожидания. Для оценки мат. ожиданий по выборкам мы будем пользоваться бутстрэпом - методом генерации "новых" выборок из одной с помощью выбора объектов с возвращением. Разберем несколько шагов на пути к оценке смещения и разброса.
#
# #### Приближенное вычисление интегралов
# На занятиях мы разбирали примеры аналитического вычисления смещения и разброса нескольких алгоритмов обучения. Для большинства моделей данных и алгоритмов обучения аналитически рассчитать математические ожидания в формулах не удастся. Однако мат. ожидания можно оценивать приближенно. Чтобы оценить математическое ожидание $\mathbb{E}_{\bar z} f(\bar z)$ функции от многомерной случайной величины $\bar z = (z_1, \dots, z_d)$, $\bar z \sim p(\bar z)$, можно сгенерировать выборку из распределения $p(\bar z)$ и усреднить значение функции на элементах этой выборки:
# $$\mathbb{E}_{\bar z} f(z) = \int f(\bar z) p(\bar z) d \bar z \approx \frac 1 m \sum_{i=1}^m f(\bar z_i), \, \bar z_i \sim p(\bar z), i = 1, \dots, m.$$
#
# Например, оценим $\mathbb{E}_z z^2,$ $z \sim \mathcal{N}(\mu=5, \sigma=3)$ (из теории вероятностей мы знаем, что
# $\mathbb{E}_z z^2 = \sigma^2 + \mu^2 = 34$):

# %%
z = np.random.normal(loc=5, scale=3, size=1000)
(z**2).mean()
# Out:
# 34.02156117221393

# %% [markdown]
# #### Оценивание $\mathbb{E}_{x, y}$
# Оценить мат. ожидания по $x$ и по $x, y$, встречающиеся во всех трех компонентах разложения, несложно, потому что у нас есть выборка объектов из распределения данных $p(x, y)$:
# $$ \mathbb{E}_{x} f(x) \approx \frac 1 N \sum_{i=1}^N f(x_i), \quad
# \mathbb{E}_{x, y} f(x, y) \approx \frac 1 N \sum_{i=1}^N f(x_i, y_i),$$
# где $N$ - число объектов в выборке, $\{(x_i, y_i)\}_{i=1}^N$ - сама выборка.
#
# #### Оценивание $\mathbb{E}_X$ с помощью бутстрапа
# Чтобы оценить мат. ожидание по $X$, нам понадобится выборка из выборок:
# $$\mathbb{E}_X f(X) \approx \frac 1 s \sum_{j=1}^s f(X_j),$$
# где $X_j$ - $j$-я выборка. Чтобы их получить, мы можем воспользоваться бутстрапом - методом генерации выборок на основе выбора объектов с возвращением. Чтобы составить одну выборку, будем $N$ раз выбирать индекс объекта $i \sim \text{Uniform}(1 \dots N)$ и добавлять $i$-ю пару (объект, целевая переменная) в выборку. В результате в каждой выборке могут появиться повторяющиеся объекты, а какие-то объекты могут вовсе не войти в некоторые выборки.
#
# #### Итоговый алгоритм оценки смещения и разброса алгоритма $a$
# 1. Сгенерировать $s$ выборок $X_j$ методом бутстрапа.
# 1. На каждой выборке $X_j$ обучить алгоритм $a_j$.
# 1. Для каждой выборки $X_j$ определить множество объектов $T_j$, не вошедших в нее (out-of-bag). Вычислить предсказания алгоритма $a_j$ на объектах $T_j$.
#
# Поскольку у нас есть только один ответ для каждого объекта, мы будем считать шум равным 0, а $\mathbb{E}[y|x]$ равным имеющемуся правильному ответу для объекта $x$.
#
# Итоговые оценки:
# * Смещение: для одного объекта - квадрат разности среднего предсказания и правильного ответа. Среднее предсказание берется только по тем алгоритмам $a_j$, для которых этот объект входил в out-of-bag выборку $T_j$. Для получения общего смещения выполнить усреденение смещений по объектам.
# * Разброс: для одного объекта - выборочная дисперсия предсказаний алгоритмов $a_j$, для которых этот объект входил в out-of-bag выборку $T_j$. Для получения общего разброса выполнить усреденение разбросов по объектам.
# * Ошибка $L$: усреднить квадраты разностей предсказания и правильного ответа по всем выполненным предсказаниям для всех объектов.
#
# В результате должно получиться, что ошибка приблизительно равна сумме смещения и разброса!
#
# Алгоритм также вкратце описан по [ссылке](https://web.engr.oregonstate.edu/~tgd/classes/534/slides/part9.pdf) (слайды 19-21).
#
# __Задание 1. (1. балл)__
#
# Реализуйте описанный алгоритм. Обратите внимание, что если объект не вошел ни в одну из out-of-bag выборок, учитывать его в вычислении итоговых величин не нужно. Как обычно, разрешается использовать только один цикл - по выборкам (от 0 до num_runs-1).

# %%
import random
def compute_biase_variance(regressor, X, y, num_runs=1000):
    """
    :param regressor: sklearn estimator with fit(...) and predict(...) method
    :param X: numpy-array representing training set ob objects, shape [n_obj, n_feat]
    :param y: numpy-array representing target for training objects, shape [n_obj]
    :param num_runs: int, number of samples (s in the description of the algorithm)

    :returns: bias (float), variance (float), error (float)
    each value is computed using bootstrap
    """
    predicted_all = np.zeros(X.shape[0])
    sq = predicted_all.copy()
    counter = predicted_all.copy()
    loss = predicted_all.copy()
    for i in range(num_runs):
      inds = []
      for j in range(X.shape[0]):
         inds.append(random.randint(0, X.shape[0] - 1))
      regressor.fit(X[inds], y[inds])
      OOB = []
      for k in range(X.shape[0]):
         if k not in inds:
            OOB.append(k)
      predicted = regressor.predict(X[OOB])
      predicted_all[OOB] += predicted
      sq[OOB] += predicted ** 2
      counter[OOB] += 1
      loss[OOB] += (y[OOB] - predicted) ** 2
    return (((predicted_all / counter) - y) ** 2).mean(), ((sq / counter) - (predicted_all / counter) ** 2).mean(), (loss / counter).mean()

# %% [markdown]
# **Задание 2. (0.5 баллa)**
#
# **(0.3 балла)** Оцените смещение, разброс и ошибку для трех алгоритмов с гиперпараметрами по умолчанию: линейная регрессия, решающее дерево, случайный лес.

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
print('Линейная регрессия: (смещение, разброс, ошибка):', compute_biase_variance(LinearRegression(), X, y))
print('Решающее дерево: (смещение, разброс, ошибка):', compute_biase_variance(DecisionTreeRegressor(), X, y))
print('Случайный лес: (смещение, разброс, ошибка):', compute_biase_variance(RandomForestRegressor(), X, y))
# Out:
# Линейная регрессия: (смещение, разброс, ошибка): (23.751863036000714, 0.9286848300346966, 24.68054786603534)
# Решающее дерево: (смещение, разброс, ошибка): (10.206593961981486, 12.876087459132409, 23.082681421113836)
# Случайный лес: (смещение, разброс, ошибка): (10.642016082470066, 2.2694354988321725, 12.911451581302357)

# %% [markdown]
# **(0.1 балл) (?)** Проанализируйте полученный результат. Согласуются ли полученные результаты с теми, что мы обсуждали на семинарах (с комментарием)?
#
# Сумма смещения и разброса действительно равна ошибке (с учетом небольшого допуска). Предположение выполнено. Линейная модель выдает высокое смещение и низкий разброс (достаточно грубое приближение и низкая отзывчивость к изменениям в обучающей выборке). У решающего дерева низкое смещение и высокий разброс (лучше аппроксимирует зависимость,но большая чувствительность к изменениям в обучающих данных). Случайный лес объединил достоинства обеих моделей.
#
# **(0.1 балл) (?)** Вспомните во сколько раз в теории бутстрап уменьшает разброс базового алгоритма. Выполняется ли это в ваших экспериментах? Если нет, поясните, почему.
#
# В N раз при некоррелированности базовых алгоритмов, но это очень жесткое требование, трудно выполнимое на практике, поэтому получилось, что в меньшее число раз.

# %% [markdown]
# ### Визуализация предсказаний базовых алгоритмов бэггинга
#
# В материалах лекций можно найти изображение, похожее на мишень - визуализация алгоритмов с разным смещением и разным разбросом. В центре "мишени" - правильный ответ, а "попадания" - предсказания алгоритмов, обученных по разным выборкам. Построим похожее изображение на наших данных для трех алгоритмов. Наши "мишени" будут одномерными, потому что мы решаем задачу одномерной регрессии.
#
# __Задание 3. (1.5 балла)__
#
# **(0.5 балла)** Реализуйте фукнцию plot_predictions. Она должна выполнять следующие действия:
# 1. Случайно выбрать num_test_objects пар объект-целевая переменная из выборки X, y. Получится две выборки: маленькая X_test, y_test (выбранные тестовые объекты) и X_train, y_train (остальные объекты).
# 1. Сгенерировать num_runs выборок методом бутстарапа из X_train, y_train. На каждой выборке обучить алгоритм regressor и сделать предсказания для X_test.
# 1. Нарисовать scatter-график. По оси абсцисс - объекты тестовой выборки (номера от 0 до num_test_objects-1), по оси ординат - предсказания для каждого из num_runs выборок. В итоге получится num_test_objects столбиков с точками. Для каждого тестового объекта надо отметить одним цветом (в рамках каждого номера объекта, т.е. предсказания для объектов с одинаковым номером -- одинаковым цветом, а с разными -- разными цветами) все предсказания для него, а также черным цветом отметить правильный ответ.
# 1. Подпишите оси и название графика (аргумент title).

# %%
import seaborn as sns
def plot_predictions(regressor, X, y, num_runs=100, num_test_objects=10, title=""):
    """
    plot graphics described above
    """
    indexes_for_test = np.random.choice(X.shape[0], size=num_test_objects)
    indexes_for_train = []
    for i in range(X.shape[0]):
       if i not in indexes_for_test:
          indexes_for_train.append(i)
    indexes_for_train = np.array(indexes_for_train)
    X_train = X[indexes_for_train]
    y_train = y[indexes_for_train]
    X_test = X[indexes_for_test]
    y_test = y[indexes_for_test]
    for i in range(num_runs):
       inds_ = []
       for j in range(X_train.shape[0]):
          inds_.append(random.randint(0, X_train.shape[0] - 1))
       regressor.fit(X_train[inds_], y_train[inds_])
       pred_ = regressor.predict(X_test)
       sns.scatterplot(x=np.arange(num_test_objects), y=pred_, color=sns.color_palette('muted', n_colors=num_test_objects))
    sns.scatterplot(x=np.arange(num_test_objects), y=y_test, color='black', label='правильный ответ')
    plt.xlabel('объекты тестовой выборки')
    plt.ylabel('предсказания')
    plt.title(title)
    plt.legend()

# %% [markdown]
# **(0.5 баллa)** Нарисуйте графики для линейной регрессии, решающего дерева и случайного леса. Нарисуйте три графика в строчку (это можно сделать с помощью plt.subplot) с одинаковой осью ординат (это важно для понимания масштаба разброса у разных алгоритмов):

# %%
fig, ax = plt.subplots(1, 3, figsize=(18, 8))
ax[0] = plt.subplot(1, 3, 1, sharey=ax[0])
plot_predictions(LinearRegression(), X, y, title='Линейная регрессия')
ax[1] = plt.subplot(1, 3, 2, sharey=ax[0])
plot_predictions(DecisionTreeRegressor(), X, y, title='Решающее дерево')
ax[2] = plt.subplot(1, 3, 3, sharey=ax[0])
plot_predictions(RandomForestRegressor(), X, y, title='Случайный лес')

# %% [markdown]
# **(0.5 балла) (?)** Для каждого графика прокомментируйте, как он характеризует смещение и разброс соответствующего алгоритма.
#
# У линейной регрессии низкий разброс (по сравнению с другими графиками точки находятся близко друг к другу), но большое смещение (концентрация точек далеко от черных правильных ответов). Это происходит потому, что линейные модели не сильно реагируют на изменения в обучающей выборке (низкий разброс), но и приближают модель не слишком точно, из-за чего возникает смещение.
#
# У решающего дерева, ожидаемо, большой разброс и низкое смещение. Оно реагиркет на малейшие изменения в обучающей выборке (разброс) и неплохо приближает модель (смещение).
#
# Случайный лес объединяет лучшие качества линейной регресии и решающего дерева и имеет сравнительно низкое смещение и низкий разброс.

# %% [markdown]
# ### Часть 2. Градиентный бустинг

# %% [markdown]
# **Задание 4 (0.5 балла)**
#
# Мы будем использовать данные из [соревнования](https://www.kaggle.com/t/b710e05dc0bd424995ca94da5b639869) (вам нужны только данные, посылать туда ничего не надо).
# * Загрузите таблицу application_train.csv;
# * Запишите в Y столбец с целевой переменной (TARGET);
# * Удалите ненужные столбцы:
#     * Воспользуйтесь описанием соревнования
#     * При желании, воспользуйтесь методами feature selection/стат. методами, если хотите. Объясните, что использовали и почему решили выкинуть тот или иной признак.
# * Определите тип столбцов и заполните пропуски - стратегия произвольная;
# * Разбейте выборку в соотношении 70:30 с random_state=0. Если считаете нужным, сделайте сбалансированное по классам разбиение.
#
# Так как в данных имеется значительный дисбаланс классов, в качестве метрики качества везде будем использовать площадь под precision-recall кривой (AUC-PR).

# %%
! brew install libomp
! pip install --no-binary lightgbm --install-option='--nomp' 'lightgbm==3.3.2'

! pip install catboost
# Out:
# /bin/bash: line 1: brew: command not found
#
# Usage:
#   pip3 install [options] <requirement specifier> [package-index-options] ...
#   pip3 install [options] -r <requirements file> [package-index-options] ...
#   pip3 install [options] [-e] <vcs project url> ...
#   pip3 install [options] [-e] <local project path> ...
#   pip3 install [options] <archive url/path> ...
#
# no such option: --install-option
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.7/98.7 MB 9.6 MB/s eta 0:00:00
# ...

# %%
! pip install lightgbm

# %%
import pandas as pd
# !wget  -O 'train.csv' -q 'https://www.dropbox.com/scl/fi/ezlztkslv7e4bh6xxdd6m/application_train.csv?rlkey=joogrwherhs8g4kih6lfsijq4&dl=0'
data = pd.read_csv('train.csv')
data_copy = data.copy()
Y = data.TARGET
from sklearn.feature_selection import SelectKBest, f_classif
#Оставим 50 наиболее значимых признаков, которые наиболее сильно коррелируют с целевой переменной.
#f_classif-поскольку решается задача классификации

#categorical подбирались в процессе просмотра датафрейма и установления всех категориальных принаков
categorical = ['NAME_CONTRACT_TYPE', 'CODE_GENDER', 'FLAG_OWN_CAR', 'FLAG_OWN_REALTY', 'NAME_TYPE_SUITE', \
               'NAME_INCOME_TYPE', 'NAME_EDUCATION_TYPE', 'NAME_FAMILY_STATUS', 'NAME_HOUSING_TYPE', \
               'OCCUPATION_TYPE', 'WEEKDAY_APPR_PROCESS_START', 'ORGANIZATION_TYPE', 'WALLSMATERIAL_MODE', \
               'HOUSETYPE_MODE', 'EMERGENCYSTATE_MODE', 'FONDKAPREMONT_MODE']
data = data.fillna(data.mode().iloc[0])
#пропуски заполняются наиболее частыми значениями
selector = SelectKBest(f_classif, k=50)
data = data.drop(['TARGET', 'SK_ID_CURR'], axis=1)
#Удаляется не только целевая переменная, но и id по 2 причинам: id как признак приводит к переобучению, при OHE кодировании эти (уникальные)
#признаки колоссально увеличат количество признаков
data_cat = data[categorical]
data_cat = pd.DataFrame(data_cat)
data = data.drop(categorical, axis=1)
#Сразу в этом (подготовительном) задании удаляю категориальные признаки, поскольку с ними SelectKBest не работает,
#а уже в следующем задании  категориальные признаки нужно удалить
data = selector.fit_transform(data, Y)
data_copy = data.copy()
data_copy = pd.DataFrame(data_copy)
#data = data.drop(['TARGET', 'SK_ID_CURR', categorical], axis=1)
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data, Y, train_size=0.7, random_state=0)
print(X_train.shape)
# Out:
# (150679, 50)

# %% [markdown]
# **Задание 5 (1 балл)**

# %% [markdown]
# **(0.4 баллa)** Обучите реализации градиентного бустинга LightGBM и Catboost на вещественных признаках без подбора параметров.
#
# **(0.6 баллa) (?) Получилась ли заметная разнциа в качестве? Как вы думаете, почему?**
#
# **Замечание:**
# * В этом и последующих экспериментах необходимо измерять время обучения моделей.

# %%
from catboost import CatBoostClassifier
from sklearn.metrics import roc_auc_score
from lightgbm import LGBMClassifier
import time
start = time.time()
clf = CatBoostClassifier(logging_level='Silent')
clf.fit(X_train, y_train)
from sklearn.metrics import auc, precision_recall_curve, roc_auc_score, roc_curve
precision, recall, thresholds = precision_recall_curve(y_test, clf.predict_proba(X_test)[:, 1])
print("Время работы CatBoost: ", time.time() - start)
print('PR-AUC для CatBoost= ', '%.5f' % auc(recall, precision))
start = time.time()
clf = LGBMClassifier()
clf.fit(X_train, y_train)
precision, recall, thresholds = precision_recall_curve(y_test, clf.predict_proba(X_test)[:, 1])
print("Время работв LightGBM: ", time.time() - start)
print('PR-AUC для LightGBM= ', '%.5f' % auc(recall, precision))
# Out:
# Время работв CatBoost:  99.87619137763977
# PR-AUC для CatBoost=  0.22816
# [LightGBM] [Info] Number of positive: 12260, number of negative: 138419
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.086231 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 7805
# [LightGBM] [Info] Number of data points in the train set: 150679, number of used features: 50
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.081365 -> initscore=-2.423943
# [LightGBM] [Info] Start training from score -2.423943
# Время работв LightGBM:  4.8098509311676025
# PR-AUC для LightGBM=  0.23481

# %% [markdown]
# Заметной разницы в качестве замечено не было (LightGBM немного лучше CatBoost), возможно, это связано с тем, что сейчас обрабатывались данные без категориальных переменных (с которыми лучше справляется CatBoost). Заметна существенная разница во времени работы этих градиентных бустингов: CatBoost работает в 10,5 раз дольше LightGBM на данном датасете. Оба алгоритма показали не очень высокое качество.

# %% [markdown]
# __Задание 6. (2 балла)__
#
# **(1. балл)** Подберите оптимальные с точки зрения метрики качества параметры алгоритмов, изменяя:
#
# * глубину деревьев;
# * количество деревьев;
# * темп обучения;
#
# Масштаб значений предлагается посмотреть [тут](https://github.com/esokolov/ml-course-hse/blob/master/2019-fall/seminars/sem10-gbm.ipynb).
#
# **(1 балл) (?)** Проанализируйте соотношения получившихся оптимальных глубины и количества деревьев в зависимости от алгоритма.**
#
# **Если на перебор гиперпараметров уходит много времени, то переберите значениях каких-нибудь 1-2 гиперпараметров, а не всех предложенных 3**

# %% [markdown]
# Будем подбирать параметры "количество деревьев" и "темп обучения" последовательно для разных глубин деревьев.

# %%
import seaborn as sns
import time
# %config InlineBackend.figure_format = 'svg'
import matplotlib.pyplot as plt
from sklearn.metrics import roc_auc_score
from sklearn.metrics import auc, precision_recall_curve, roc_auc_score, roc_curve
from lightgbm import LGBMClassifier
import warnings
warnings.filterwarnings('ignore')
warnings.simplefilter('ignore')
ind = 0
tmp = pd.DataFrame(columns=["learning_rate", "n_estimators", "pr"])
for i in [0.001, 0.01, 0.05, 0.1, 0.5, 1, 2]:
  for j in [20, 30, 50, 100, 300, 1000, 1500]:
    start = time.time()
    clf = LGBMClassifier(max_depth=3, learning_rate=i, n_estimators=j, verbose=-1)
    clf.fit(X_train, y_train)
    precision, recall, thresholds = precision_recall_curve(y_test, clf.predict_proba(X_test)[:, 1])
    pr = auc(recall, precision)
    print(ind, 'Глубина 3, темп обучения', i, 'количество деревьев', j, '-> время', time.time() - start)
    new_line = [i, j, pr]
    tmp.loc[ind] = new_line
    ind += 1
fig, ax = plt.subplots(figsize=(20,10))
a = sns.heatmap(tmp.pivot(index='learning_rate', columns='n_estimators', values='pr'), annot=True, fmt=".3f", vmax=0.245, cmap='BuPu', ax=ax)
plt.xlabel("число итераций бустинга (количество деревьев)")
plt.ylabel("темп (скорость) обучения")
plt.title("Зависимость PR-AUC для LightGBM при глубине деревьев 3 от других параметров")
# Out:
# 0 Глубина 3, темп обучения 0.001 количество деревьев 20 -> время 1.7780234813690186
# 1 Глубина 3, темп обучения 0.001 количество деревьев 30 -> время 2.6882898807525635
# 2 Глубина 3, темп обучения 0.001 количество деревьев 50 -> время 2.8729305267333984
# 3 Глубина 3, темп обучения 0.001 количество деревьев 100 -> время 3.4179561138153076
# 4 Глубина 3, темп обучения 0.001 количество деревьев 300 -> время 8.822919845581055
# 5 Глубина 3, темп обучения 0.001 количество деревьев 1000 -> время 26.356525897979736
# 6 Глубина 3, темп обучения 0.001 количество деревьев 1500 -> время 40.62801718711853
# 7 Глубина 3, темп обучения 0.01 количество деревьев 20 -> время 1.7323627471923828
# 8 Глубина 3, темп обучения 0.01 количество деревьев 30 -> время 2.4376332759857178
# 9 Глубина 3, темп обучения 0.01 количество деревьев 50 -> время 3.341569662094116
# 10 Глубина 3, темп обучения 0.01 количество деревьев 100 -> время 3.595914363861084
# ...

# %%
plt.show()

# %%
import seaborn as sns
import time
# %config InlineBackend.figure_format = 'svg'
import matplotlib.pyplot as plt
from sklearn.metrics import roc_auc_score
from sklearn.metrics import auc, precision_recall_curve, roc_auc_score, roc_curve
from lightgbm import LGBMClassifier
import warnings
warnings.filterwarnings('ignore')
warnings.simplefilter('ignore')
ind = 0
tmp = pd.DataFrame(columns=["learning_rate", "n_estimators", "pr"])
for i in [0.001, 0.01, 0.05, 0.1, 0.5, 1, 2]:
  for j in [20, 30, 50, 100, 300, 1000, 1500]:
    start = time.time()
    clf = LGBMClassifier(max_depth=4, learning_rate=i, n_estimators=j, verbose=-1)
    clf.fit(X_train, y_train)
    precision, recall, thresholds = precision_recall_curve(y_test, clf.predict_proba(X_test)[:, 1])
    pr = auc(recall, precision)
    print(ind, 'Глубина 4, темп обучения', i, 'количество деревьев', j, '-> время', time.time() - start)
    new_line = [i, j, pr]
    tmp.loc[ind] = new_line
    ind += 1
fig, ax = plt.subplots(figsize=(20,10))
a = sns.heatmap(tmp.pivot(index='learning_rate', columns='n_estimators', values='pr'), annot=True, fmt=".3f", vmax=0.245, cmap='BuPu', ax=ax)
plt.xlabel("число итераций бустинга (количество деревьев)")
plt.ylabel("темп (скорость) обучения")
plt.title("Зависимость PR-AUC для LightGBM при глубине деревьев 4 от других параметров")
# Out:
# 0 Глубина 4, темп обучения 0.001 количество деревьев 20 -> время 1.8054096698760986
# 1 Глубина 4, темп обучения 0.001 количество деревьев 30 -> время 2.802665948867798
# 2 Глубина 4, темп обучения 0.001 количество деревьев 50 -> время 2.925887107849121
# 3 Глубина 4, темп обучения 0.001 количество деревьев 100 -> время 3.7537307739257812
# 4 Глубина 4, темп обучения 0.001 количество деревьев 300 -> время 10.390114307403564
# 5 Глубина 4, темп обучения 0.001 количество деревьев 1000 -> время 31.888486862182617
# 6 Глубина 4, темп обучения 0.001 количество деревьев 1500 -> время 47.83314657211304
# 7 Глубина 4, темп обучения 0.01 количество деревьев 20 -> время 1.9129226207733154
# 8 Глубина 4, темп обучения 0.01 количество деревьев 30 -> время 2.9483087062835693
# 9 Глубина 4, темп обучения 0.01 количество деревьев 50 -> время 2.895780563354492
# 10 Глубина 4, темп обучения 0.01 количество деревьев 100 -> время 3.8480284214019775
# ...

# %%
plt.show()

# %%
import seaborn as sns
import time
# %config InlineBackend.figure_format = 'svg'
import matplotlib.pyplot as plt
from sklearn.metrics import roc_auc_score
from sklearn.metrics import auc, precision_recall_curve, roc_auc_score, roc_curve
from lightgbm import LGBMClassifier
import warnings
warnings.filterwarnings('ignore')
warnings.simplefilter('ignore')
ind = 0
tmp = pd.DataFrame(columns=["learning_rate", "n_estimators", "pr"])
for i in [0.001, 0.01, 0.05, 0.1, 0.5, 1, 2]:
  for j in [20, 30, 50, 100, 300, 1000, 1500]:
    start = time.time()
    clf = LGBMClassifier(max_depth=5, learning_rate=i, n_estimators=j, verbose=-1)
    clf.fit(X_train, y_train)
    precision, recall, thresholds = precision_recall_curve(y_test, clf.predict_proba(X_test)[:, 1])
    pr = auc(recall, precision)
    print(ind, 'Глубина 5, темп обучения', i, 'количество деревьев', j, '-> время', time.time() - start)
    new_line = [i, j, pr]
    tmp.loc[ind] = new_line
    ind += 1
fig, ax = plt.subplots(figsize=(20,10))
a = sns.heatmap(tmp.pivot(index='learning_rate', columns='n_estimators', values='pr'), annot=True, fmt=".3f", vmax=0.245, cmap='BuPu', ax=ax)
plt.xlabel("число итераций бустинга (количество деревьев)")
plt.ylabel("темп (скорость) обучения")
plt.title("Зависимость PR-AUC для LightGBM при глубине деревьев 5 от других параметров")
# Out:
# 0 Глубина 5, темп обучения 0.001 количество деревьев 20 -> время 2.2743113040924072
# 1 Глубина 5, темп обучения 0.001 количество деревьев 30 -> время 3.15297532081604
# 2 Глубина 5, темп обучения 0.001 количество деревьев 50 -> время 2.908590793609619
# 3 Глубина 5, темп обучения 0.001 количество деревьев 100 -> время 4.292608737945557
# 4 Глубина 5, темп обучения 0.001 количество деревьев 300 -> время 13.454728603363037
# 5 Глубина 5, темп обучения 0.001 количество деревьев 1000 -> время 39.37022376060486
# 6 Глубина 5, темп обучения 0.001 количество деревьев 1500 -> время 59.27993845939636
# 7 Глубина 5, темп обучения 0.01 количество деревьев 20 -> время 1.847599983215332
# 8 Глубина 5, темп обучения 0.01 количество деревьев 30 -> время 2.149404764175415
# 9 Глубина 5, темп обучения 0.01 количество деревьев 50 -> время 3.0402441024780273
# 10 Глубина 5, темп обучения 0.01 количество деревьев 100 -> время 5.427766799926758
# ...

# %%
plt.show()

# %%
import seaborn as sns
import time
# %config InlineBackend.figure_format = 'svg'
import matplotlib.pyplot as plt
from sklearn.metrics import roc_auc_score
from sklearn.metrics import auc, precision_recall_curve, roc_auc_score, roc_curve
from lightgbm import LGBMClassifier
import warnings
warnings.filterwarnings('ignore')
warnings.simplefilter('ignore')
ind = 0
tmp = pd.DataFrame(columns=["learning_rate", "n_estimators", "pr"])
for i in [0.001, 0.01, 0.05, 0.1, 0.5, 1, 2]:
  for j in [20, 30, 50, 100, 300, 1000, 1500]:
    start = time.time()
    clf = LGBMClassifier(max_depth=6, learning_rate=i, n_estimators=j, verbose=-1)
    clf.fit(X_train, y_train)
    precision, recall, thresholds = precision_recall_curve(y_test, clf.predict_proba(X_test)[:, 1])
    pr = auc(recall, precision)
    print(ind, 'Глубина 6, темп обучения', i, 'количество деревьев', j, '-> время', time.time() - start)
    new_line = [i, j, pr]
    tmp.loc[ind] = new_line
    ind += 1
fig, ax = plt.subplots(figsize=(20,10))
a = sns.heatmap(tmp.pivot(index='learning_rate', columns='n_estimators', values='pr'), annot=True, fmt=".3f", vmax=0.245, cmap='BuPu', ax=ax)
plt.xlabel("число итераций бустинга (количество деревьев)")
plt.ylabel("темп (скорость) обучения")
plt.title("Зависимость PR-AUC для LightGBM при глубине деревьев 6 от других параметров")
# Out:
# 0 Глубина 6, темп обучения 0.001 количество деревьев 20 -> время 1.8756701946258545
# 1 Глубина 6, темп обучения 0.001 количество деревьев 30 -> время 2.174488067626953
# 2 Глубина 6, темп обучения 0.001 количество деревьев 50 -> время 3.8930811882019043
# 3 Глубина 6, темп обучения 0.001 количество деревьев 100 -> время 4.701372385025024
# 4 Глубина 6, темп обучения 0.001 количество деревьев 300 -> время 12.466940879821777
# 5 Глубина 6, темп обучения 0.001 количество деревьев 1000 -> время 41.36384868621826
# 6 Глубина 6, темп обучения 0.001 количество деревьев 1500 -> время 62.4674756526947
# 7 Глубина 6, темп обучения 0.01 количество деревьев 20 -> время 1.9024312496185303
# 8 Глубина 6, темп обучения 0.01 количество деревьев 30 -> время 2.1889395713806152
# 9 Глубина 6, темп обучения 0.01 количество деревьев 50 -> время 4.011116981506348
# 10 Глубина 6, темп обучения 0.01 количество деревьев 100 -> время 4.932987451553345
# ...

# %%
plt.show()

# %%
import seaborn as sns
import time
# %config InlineBackend.figure_format = 'svg'
import matplotlib.pyplot as plt
from sklearn.metrics import roc_auc_score
from sklearn.metrics import auc, precision_recall_curve, roc_auc_score, roc_curve
from lightgbm import LGBMClassifier
import warnings
warnings.filterwarnings('ignore')
warnings.simplefilter('ignore')
ind = 0
tmp = pd.DataFrame(columns=["learning_rate", "n_estimators", "pr"])
for i in [0.001, 0.01, 0.05, 0.1, 0.5, 1, 2]:
  for j in [20, 30, 50, 100, 300, 1000, 1500]:
    start = time.time()
    clf = LGBMClassifier(max_depth=7, learning_rate=i, n_estimators=j, verbose=-1)
    clf.fit(X_train, y_train)
    precision, recall, thresholds = precision_recall_curve(y_test, clf.predict_proba(X_test)[:, 1])
    pr = auc(recall, precision)
    print(ind, 'Глубина 7, темп обучения', i, 'количество деревьев', j, '-> время', time.time() - start)
    new_line = [i, j, pr]
    tmp.loc[ind] = new_line
    ind += 1
fig, ax = plt.subplots(figsize=(20,10))
a = sns.heatmap(tmp.pivot(index='learning_rate', columns='n_estimators', values='pr'), annot=True, fmt=".3f", vmax=0.245, cmap='BuPu', ax=ax)
plt.xlabel("число итераций бустинга (количество деревьев)")
plt.ylabel("темп (скорость) обучения")
plt.title("Зависимость PR-AUC для LightGBM при глубине деревьев 7 от других параметров")
# Out:
# 0 Глубина 7, темп обучения 0.001 количество деревьев 20 -> время 2.240004062652588
# 1 Глубина 7, темп обучения 0.001 количество деревьев 30 -> время 3.1792261600494385
# 2 Глубина 7, темп обучения 0.001 количество деревьев 50 -> время 2.9481074810028076
# 3 Глубина 7, темп обучения 0.001 количество деревьев 100 -> время 4.5792460441589355
# 4 Глубина 7, темп обучения 0.001 количество деревьев 300 -> время 12.92341136932373
# 5 Глубина 7, темп обучения 0.001 количество деревьев 1000 -> время 44.14323043823242
# 6 Глубина 7, темп обучения 0.001 количество деревьев 1500 -> время 66.13407254219055
# 7 Глубина 7, темп обучения 0.01 количество деревьев 20 -> время 1.9109416007995605
# 8 Глубина 7, темп обучения 0.01 количество деревьев 30 -> время 2.2711925506591797
# 9 Глубина 7, темп обучения 0.01 количество деревьев 50 -> время 2.9786226749420166
# 10 Глубина 7, темп обучения 0.01 количество деревьев 100 -> время 6.4100401401519775
# ...

# %%
plt.show()

# %%
import seaborn as sns
# %config InlineBackend.figure_format = 'svg'
import matplotlib.pyplot as plt
from sklearn.metrics import roc_auc_score
from sklearn.metrics import auc, precision_recall_curve, roc_auc_score, roc_curve
from catboost import CatBoostClassifier
import warnings
warnings.filterwarnings('ignore')
warnings.simplefilter('ignore')
ind = 0
tmp = pd.DataFrame(columns=["learning_rate", "iterations", "pr"])
for i in [0.001, 0.01, 0.05, 0.1, 0.5, 1, 2]:
  for j in [20, 30, 50, 100, 300, 1000, 1500]:
    start = time.time()
    clf = CatBoostClassifier(logging_level='Silent', depth=3, learning_rate=i, iterations=j)
    clf.fit(X_train, y_train)
    precision, recall, thresholds = precision_recall_curve(y_test, clf.predict_proba(X_test)[:, 1])
    print(ind, 'Глубина 3, темп обучения', i, 'количество деревьев', j, '-> время', time.time() - start)
    new_line = [i, j, auc(recall, precision)]
    tmp.loc[ind] = new_line
    ind += 1
fig, ax = plt.subplots(figsize=(20,10))
a = sns.heatmap(tmp.pivot(index='learning_rate', columns='iterations', values='pr'), annot=True, fmt=".3f", vmax=0.245, cmap='BuPu', ax=ax)
plt.xlabel("число итераций бустинга (количество деревьев)")
plt.ylabel("темп (скорость) обучения")
plt.title("Зависимость PR-AUC для CatBoost при глубине деревьев 3 от других параметров")
# Out:
# 0 Глубина 3, темп обучения 0.001 количество деревьев 20 -> время 4.43342924118042
# 1 Глубина 3, темп обучения 0.001 количество деревьев 30 -> время 4.549422025680542
# 2 Глубина 3, темп обучения 0.001 количество деревьев 50 -> время 7.603567600250244
# 3 Глубина 3, темп обучения 0.001 количество деревьев 100 -> время 6.886175155639648
# 4 Глубина 3, темп обучения 0.001 количество деревьев 300 -> время 17.34178352355957
# 5 Глубина 3, темп обучения 0.001 количество деревьев 1000 -> время 45.17734384536743
# 6 Глубина 3, темп обучения 0.001 количество деревьев 1500 -> время 63.030035972595215
# 7 Глубина 3, темп обучения 0.01 количество деревьев 20 -> время 5.024422645568848
# 8 Глубина 3, темп обучения 0.01 количество деревьев 30 -> время 6.219043016433716
# 9 Глубина 3, темп обучения 0.01 количество деревьев 50 -> время 5.342900514602661
# 10 Глубина 3, темп обучения 0.01 количество деревьев 100 -> время 9.469193458557129
# ...

# %%
plt.show()

# %%
import seaborn as sns
# %config InlineBackend.figure_format = 'svg'
import matplotlib.pyplot as plt
from sklearn.metrics import roc_auc_score
from sklearn.metrics import auc, precision_recall_curve, roc_auc_score, roc_curve
from catboost import CatBoostClassifier
import warnings
warnings.filterwarnings('ignore')
warnings.simplefilter('ignore')
ind = 0
tmp = pd.DataFrame(columns=["learning_rate", "iterations", "pr"])
for i in [0.001, 0.01, 0.05, 0.1, 0.5, 1, 2]:
  for j in [20, 30, 50, 100, 300, 1000, 1500]:
    start = time.time()
    clf = CatBoostClassifier(logging_level='Silent', depth=4, learning_rate=i, iterations=j)
    clf.fit(X_train, y_train)
    precision, recall, thresholds = precision_recall_curve(y_test, clf.predict_proba(X_test)[:, 1])
    print(ind, 'Глубина 4, темп обучения', i, 'количество деревьев', j, '-> время', time.time() - start)
    new_line = [i, j, auc(recall, precision)]
    tmp.loc[ind] = new_line
    ind += 1
fig, ax = plt.subplots(figsize=(20,10))
a = sns.heatmap(tmp.pivot(index='learning_rate', columns='iterations', values='pr'), annot=True, fmt=".3f", vmax=0.245, cmap='BuPu', ax=ax)
plt.xlabel("число итераций бустинга (количество деревьев)")
plt.ylabel("темп (скорость) обучения")
plt.title("Зависимость PR-AUC для CatBoost при глубине деревьев 4 от других параметров")
# Out:
# 0 Глубина 4, темп обучения 0.001 количество деревьев 20 -> время 6.807454347610474
# 1 Глубина 4, темп обучения 0.001 количество деревьев 30 -> время 4.898305892944336
# 2 Глубина 4, темп обучения 0.001 количество деревьев 50 -> время 7.915666341781616
# 3 Глубина 4, темп обучения 0.001 количество деревьев 100 -> время 7.611631631851196
# 4 Глубина 4, темп обучения 0.001 количество деревьев 300 -> время 19.617894649505615
# 5 Глубина 4, темп обучения 0.001 количество деревьев 1000 -> время 51.496654987335205
# 6 Глубина 4, темп обучения 0.001 количество деревьев 1500 -> время 73.79813265800476
# 7 Глубина 4, темп обучения 0.01 количество деревьев 20 -> время 6.745924711227417
# 8 Глубина 4, темп обучения 0.01 количество деревьев 30 -> время 4.757871150970459
# 9 Глубина 4, темп обучения 0.01 количество деревьев 50 -> время 7.822213888168335
# 10 Глубина 4, темп обучения 0.01 количество деревьев 100 -> время 7.47109842300415
# ...

# %%
plt.show()

# %%
import seaborn as sns
# %config InlineBackend.figure_format = 'svg'
import matplotlib.pyplot as plt
from sklearn.metrics import roc_auc_score
from sklearn.metrics import auc, precision_recall_curve, roc_auc_score, roc_curve
from catboost import CatBoostClassifier
import warnings
warnings.filterwarnings('ignore')
warnings.simplefilter('ignore')
ind = 0
tmp = pd.DataFrame(columns=["learning_rate", "iterations", "pr"])
for i in [0.001, 0.01, 0.05, 0.1, 0.5, 1, 2]:
  for j in [20, 30, 50, 100, 300, 1000, 1500]:
    start = time.time()
    clf = CatBoostClassifier(logging_level='Silent', depth=5, learning_rate=i, iterations=j)
    clf.fit(X_train, y_train)
    precision, recall, thresholds = precision_recall_curve(y_test, clf.predict_proba(X_test)[:, 1])
    print(ind, 'Глубина 5, темп обучения', i, 'количество деревьев', j, '-> время', time.time() - start)
    new_line = [i, j, auc(recall, precision)]
    tmp.loc[ind] = new_line
    ind += 1
fig, ax = plt.subplots(figsize=(20,10))
a = sns.heatmap(tmp.pivot(index='learning_rate', columns='iterations', values='pr'), annot=True, fmt=".3f", vmax=0.245, cmap='BuPu', ax=ax)
plt.xlabel("число итераций бустинга (количество деревьев)")
plt.ylabel("темп (скорость) обучения")
plt.title("Зависимость PR-AUC для CatBoost при глубине деревьев 5 от других параметров")
# Out:
# 0 Глубина 5, темп обучения 0.001 количество деревьев 20 -> время 6.9018025398254395
# 1 Глубина 5, темп обучения 0.001 количество деревьев 30 -> время 4.912933111190796
# 2 Глубина 5, темп обучения 0.001 количество деревьев 50 -> время 8.04080843925476
# 3 Глубина 5, темп обучения 0.001 количество деревьев 100 -> время 7.9826812744140625
# 4 Глубина 5, темп обучения 0.001 количество деревьев 300 -> время 21.127836227416992
# 5 Глубина 5, темп обучения 0.001 количество деревьев 1000 -> время 56.56002855300903
# 6 Глубина 5, темп обучения 0.001 количество деревьев 1500 -> время 81.26723074913025
# 7 Глубина 5, темп обучения 0.01 количество деревьев 20 -> время 6.777789115905762
# 8 Глубина 5, темп обучения 0.01 количество деревьев 30 -> время 5.007124900817871
# 9 Глубина 5, темп обучения 0.01 количество деревьев 50 -> время 8.10361623764038
# 10 Глубина 5, темп обучения 0.01 количество деревьев 100 -> время 7.99021053314209
# ...

# %%
plt.show()

# %%
import seaborn as sns
# %config InlineBackend.figure_format = 'svg'
import matplotlib.pyplot as plt
from sklearn.metrics import roc_auc_score
from sklearn.metrics import auc, precision_recall_curve, roc_auc_score, roc_curve
from catboost import CatBoostClassifier
import warnings
warnings.filterwarnings('ignore')
warnings.simplefilter('ignore')
ind = 0
tmp = pd.DataFrame(columns=["learning_rate", "iterations", "pr"])
for i in [0.001, 0.01, 0.05, 0.1, 0.5, 1, 2]:
  for j in [20, 30, 50, 100, 300, 1000, 1500]:
    start = time.time()
    clf = CatBoostClassifier(logging_level='Silent', depth=6, learning_rate=i, iterations=j)
    clf.fit(X_train, y_train)
    precision, recall, thresholds = precision_recall_curve(y_test, clf.predict_proba(X_test)[:, 1])
    print(ind, 'Глубина 6, темп обучения', i, 'количество деревьев', j, '-> время', time.time() - start)
    new_line = [i, j, auc(recall, precision)]
    tmp.loc[ind] = new_line
    ind += 1
fig, ax = plt.subplots(figsize=(20,10))
a = sns.heatmap(tmp.pivot(index='learning_rate', columns='iterations', values='pr'), annot=True, fmt=".3f", vmax=0.245, cmap='BuPu', ax=ax)
plt.xlabel("число итераций бустинга (количество деревьев)")
plt.ylabel("темп (скорость) обучения")
plt.title("Зависимость PR-AUC для CatBoost при глубине деревьев 6 от других параметров")
# Out:
# 0 Глубина 6, темп обучения 0.001 количество деревьев 20 -> время 5.5979931354522705
# 1 Глубина 6, темп обучения 0.001 количество деревьев 30 -> время 5.134242057800293
# 2 Глубина 6, темп обучения 0.001 количество деревьев 50 -> время 8.450734853744507
# 3 Глубина 6, темп обучения 0.001 количество деревьев 100 -> время 10.5387601852417
# 4 Глубина 6, темп обучения 0.001 количество деревьев 300 -> время 21.644454956054688
# 5 Глубина 6, темп обучения 0.001 количество деревьев 1000 -> время 65.48539662361145
# 6 Глубина 6, темп обучения 0.001 количество деревьев 1500 -> время 93.67428827285767
# 7 Глубина 6, темп обучения 0.01 количество деревьев 20 -> время 6.888152837753296
# 8 Глубина 6, темп обучения 0.01 количество деревьев 30 -> время 5.103937864303589
# 9 Глубина 6, темп обучения 0.01 количество деревьев 50 -> время 8.325935125350952
# 10 Глубина 6, темп обучения 0.01 количество деревьев 100 -> время 8.771629333496094
# ...

# %%
plt.show()

# %%
import seaborn as sns
# %config InlineBackend.figure_format = 'svg'
import matplotlib.pyplot as plt
from sklearn.metrics import roc_auc_score
from sklearn.metrics import auc, precision_recall_curve, roc_auc_score, roc_curve
from catboost import CatBoostClassifier
import warnings
warnings.filterwarnings('ignore')
warnings.simplefilter('ignore')
ind = 0
tmp = pd.DataFrame(columns=["learning_rate", "iterations", "pr"])
for i in [0.001, 0.01, 0.05, 0.1, 0.5, 1, 2]:
  for j in [20, 30, 50, 100, 300, 1000, 1500]:
    start = time.time()
    clf = CatBoostClassifier(logging_level='Silent', depth=7, learning_rate=i, iterations=j)
    clf.fit(X_train, y_train)
    precision, recall, thresholds = precision_recall_curve(y_test, clf.predict_proba(X_test)[:, 1])
    print(ind, 'Глубина 7, темп обучения', i, 'количество деревьев', j, '-> время', time.time() - start)
    new_line = [i, j, auc(recall, precision)]
    tmp.loc[ind] = new_line
    ind += 1
fig, ax = plt.subplots(figsize=(20,10))
a = sns.heatmap(tmp.pivot(index='learning_rate', columns='iterations', values='pr'), annot=True, fmt=".3f", vmax=0.245, cmap='BuPu', ax=ax)
plt.xlabel("число итераций бустинга (количество деревьев)")
plt.ylabel("темп (скорость) обучения")
plt.title("Зависимость PR-AUC для CatBoost при глубине деревьев 7 от других параметров")
# Out:
# 0 Глубина 7, темп обучения 0.001 количество деревьев 20 -> время 6.930617094039917
# 1 Глубина 7, темп обучения 0.001 количество деревьев 30 -> время 5.449189186096191
# 2 Глубина 7, темп обучения 0.001 количество деревьев 50 -> время 8.91473388671875
# 3 Глубина 7, темп обучения 0.001 количество деревьев 100 -> время 11.951300621032715
# 4 Глубина 7, темп обучения 0.001 количество деревьев 300 -> время 24.22986626625061
# 5 Глубина 7, темп обучения 0.001 количество деревьев 1000 -> время 77.4710807800293
# 6 Глубина 7, темп обучения 0.001 количество деревьев 1500 -> время 112.6396837234497
# 7 Глубина 7, темп обучения 0.01 количество деревьев 20 -> время 4.806662321090698
# 8 Глубина 7, темп обучения 0.01 количество деревьев 30 -> время 6.01903772354126
# 9 Глубина 7, темп обучения 0.01 количество деревьев 50 -> время 8.442146301269531
# 10 Глубина 7, темп обучения 0.01 количество деревьев 100 -> время 11.927478075027466
# ...

# %%
plt.show()

# %% [markdown]
# Анализ полученных в виде тепловых карт результатов показывает, что оптимальными параметрами для LightGBM являются глубина 3, темп обучения 0.1, количество деревьев 300, pr-auc = 0.240. Для CatBoost глубина 3, темп обучения 0.05, количество деревьев 1000, pr-auc = 0.239. Как видно, преимущество имеют алгоритмы с небольшой глубиной, чтобы не усложнять модель. И параметры глубины перебирались не очень большие. Количество деревьев получилось довольно большим (особенно в случае CatBoost). Но это можно связать с довольно малым темпом обучения для CatBoost.

# %% [markdown]
# **Задание 7 (1.5 баллa)**
#
# **(1 балл)** Добавьте категориальные признаки к вещественным следующими способами:
#
# * как OHE признаки;
# * как счетчики со сглаживанием.
#
# Можно использовать библиотечные реализации; при подсчете счетчиков нельзя использовать циклы.
#
# **(0.5 баллa) (?)** Как меняется время, необходимое для обучения моделей в зависимости от способа кодирования? (Параметры можно не подбирать).

# %%
data = pd.concat([data_copy, data_cat], axis=1)
print(data_copy.shape, data_cat.shape)
categorical = ['NAME_CONTRACT_TYPE', 'CODE_GENDER', 'FLAG_OWN_CAR', 'FLAG_OWN_REALTY', 'NAME_TYPE_SUITE', \
               'NAME_INCOME_TYPE', 'NAME_EDUCATION_TYPE', 'NAME_FAMILY_STATUS', 'NAME_HOUSING_TYPE', \
               'OCCUPATION_TYPE', 'WEEKDAY_APPR_PROCESS_START', 'ORGANIZATION_TYPE', 'WALLSMATERIAL_MODE', \
               'HOUSETYPE_MODE', 'EMERGENCYSTATE_MODE', 'FONDKAPREMONT_MODE']
data = pd.get_dummies(data, columns=categorical)
print(data.shape)
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data, Y, train_size=0.7, random_state=0)
# Out:
# (215257, 50) (215257, 16)
# (215257, 190)

# %%
import numpy as np
X_train = np.array(X_train)
X_test = np.array(X_test)
y_test = np.array(y_test)
y_train = np.array(y_train)

# %%
from lightgbm import LGBMClassifier
from sklearn.metrics import auc, precision_recall_curve, roc_auc_score, roc_curve, RocCurveDisplay, PrecisionRecallDisplay
import time
start = time.time()
clf = LGBMClassifier()
clf.fit(X_train, y_train)
precision, recall, thresholds = precision_recall_curve(y_test, clf.predict_proba(X_test)[:, 1])
print('Время для LightGBM', time.time() - start)
print('PR-AUC = ', '%.5f' % auc(recall, precision))
# Out:
# [LightGBM] [Info] Number of positive: 12260, number of negative: 138419
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.143565 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 8071
# [LightGBM] [Info] Number of data points in the train set: 150679, number of used features: 183
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.081365 -> initscore=-2.423943
# [LightGBM] [Info] Start training from score -2.423943
# Время для LightGBM 5.916944742202759
# PR-AUC =  0.24044

# %%
from catboost import CatBoostClassifier
from sklearn.metrics import auc, precision_recall_curve, roc_auc_score, roc_curve, RocCurveDisplay, PrecisionRecallDisplay
import time
start = time.time()
clf = CatBoostClassifier(logging_level='Silent')
clf.fit(X_train, y_train)
precision, recall, thresholds = precision_recall_curve(y_test, clf.predict_proba(X_test)[:, 1])
print('Время для CatBoost', time.time() - start)
print('PR-AUC = ', '%.5f' % auc(recall, precision))
# Out:
# Время для CatBoost 67.87603807449341
# PR-AUC =  0.23639

# %%
import pandas as pd

! pip install category_encoders
import category_encoders as ce
data = pd.concat([data_copy, data_cat], axis=1)
print(data_copy.shape, data_cat.shape)
categorical = ['NAME_CONTRACT_TYPE', 'CODE_GENDER', 'FLAG_OWN_CAR', 'FLAG_OWN_REALTY', 'NAME_TYPE_SUITE', \
               'NAME_INCOME_TYPE', 'NAME_EDUCATION_TYPE', 'NAME_FAMILY_STATUS', 'NAME_HOUSING_TYPE', \
               'OCCUPATION_TYPE', 'WEEKDAY_APPR_PROCESS_START', 'ORGANIZATION_TYPE', 'WALLSMATERIAL_MODE', \
               'HOUSETYPE_MODE', 'EMERGENCYSTATE_MODE', 'FONDKAPREMONT_MODE']
enc = ce.TargetEncoder(cols=categorical, handle_unknown='value', smoothing=0.5).fit(data, Y)
data = enc.transform(data)
X_train, X_test, y_train, y_test = train_test_split(data, Y, train_size=0.7, random_state=0)
import numpy as np
X_train = np.array(X_train)
X_test = np.array(X_test)
y_test = np.array(y_test)
y_train = np.array(y_train)
# Out:
# ...
# (215257, 50) (215257, 16)

# %%
from lightgbm import LGBMClassifier
from sklearn.metrics import auc, precision_recall_curve, roc_auc_score, roc_curve, RocCurveDisplay, PrecisionRecallDisplay
import time
start = time.time()
clf = LGBMClassifier()
clf.fit(X_train, y_train)
precision, recall, thresholds = precision_recall_curve(y_test, clf.predict_proba(X_test)[:, 1])
print('Время для LightGBM', time.time() - start)
print('PR-AUC = ', '%.5f' % auc(recall, precision))
# Out:
# [LightGBM] [Info] Number of positive: 12260, number of negative: 138419
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.129714 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 7959
# [LightGBM] [Info] Number of data points in the train set: 150679, number of used features: 66
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.081365 -> initscore=-2.423943
# [LightGBM] [Info] Start training from score -2.423943
# Время для LightGBM 10.009771347045898
# PR-AUC =  0.23871

# %%
from catboost import CatBoostClassifier
from sklearn.metrics import auc, precision_recall_curve, roc_auc_score, roc_curve, RocCurveDisplay, PrecisionRecallDisplay
import time
start = time.time()
clf = CatBoostClassifier(logging_level='Silent')
clf.fit(X_train, y_train)
precision, recall, thresholds = precision_recall_curve(y_test, clf.predict_proba(X_test)[:, 1])
print('Время для CatBoost', time.time() - start)
print('PR-AUC = ', '%.5f' % auc(recall, precision))
# Out:
# Время для CatBoost 90.2005980014801
# PR-AUC =  0.23503

# %% [markdown]
# OHE кодирование резко увеличивает количество признаков, в отличие от счётчиков. Но при OHE кодировании обе модели проработали быстрее (факт странный, возможно это связано с использованием библиотечных счетчиков, которые так преобразуют информацию, что это впоследствии увеличивает время работы алгоритмов) и показали лучшее качество, из чего можно сделать вывод, что для данного датасета и алгоритмов OHE кодирование подходит лучше.

# %% [markdown]
# **Задание 8 (1 балл)**
#
# **(0.5 баллa)** Для CatBoost можно не делать ручную обработку категориальных признаков, а подавать как есть. Обучите модель CatBoost, не обрабатывая специально категориальные признаки, замерьте время обучения (параметры возьмите из предыдущего пункта).
#
# **(0.5 баллa) (?)**Сравните с временем обучения модели CatBoost из предыдущего пункта. Как изменилось время? Почему?

# %%
data = pd.concat([data_copy, data_cat], axis=1)
categorical = ['NAME_CONTRACT_TYPE', 'CODE_GENDER', 'FLAG_OWN_CAR', 'FLAG_OWN_REALTY', 'NAME_TYPE_SUITE', \
               'NAME_INCOME_TYPE', 'NAME_EDUCATION_TYPE', 'NAME_FAMILY_STATUS', 'NAME_HOUSING_TYPE', \
               'OCCUPATION_TYPE', 'WEEKDAY_APPR_PROCESS_START', 'ORGANIZATION_TYPE', 'WALLSMATERIAL_MODE', \
               'HOUSETYPE_MODE', 'EMERGENCYSTATE_MODE', 'FONDKAPREMONT_MODE']
X_train, X_test, y_train, y_test = train_test_split(data, Y, train_size=0.7, random_state=0)
start = time.time()
clf = CatBoostClassifier(logging_level='Silent', cat_features=categorical)
clf.fit(X_train, y_train)
precision, recall, thresholds = precision_recall_curve(y_test, clf.predict_proba(X_test)[:, 1])
print('Время для CatBoost', time.time() - start)
print('PR-AUC = ', '%.5f' % auc(recall, precision))
# Out:
# Время для CatBoost 480.46347212791443
# PR-AUC =  0.24180

# %% [markdown]
# Время обучения увеличилось в несколько раз. Это можно объяснить тем, что CatBoost самостоятельно кодирует признаки, затрачивая на это дополнительное время, возможно, также и делает это со сложной логикой. Качество улучшилось, что говорит о том, что внутренние способы обработки категориальных признаков написаны эффективно с точки зрения итогового качества.

# %% [markdown]
# **Бонус. (1 балл)**
#
# **(0.5 баллa)**Подберите оптимальные параметры для LightGBM с вещественными и категориальными признаками (предварительно обработанные каким-нибудь способом). Подберите оптимальные параметры для CatBoost с вещественными и необработанными категориальными признаками.
#
# **(0.5 баллa) (?)**Сравните качество моделей на наилучших параметрах. Какой метод получился лучше с точки зрения качества? Совпадает ли результат с вашими ожиданиями?

# %%
#LightGBM
data = pd.concat([data_copy, data_cat], axis=1)
print(data_copy.shape, data_cat.shape)
categorical = ['NAME_CONTRACT_TYPE', 'CODE_GENDER', 'FLAG_OWN_CAR', 'FLAG_OWN_REALTY', 'NAME_TYPE_SUITE', \
               'NAME_INCOME_TYPE', 'NAME_EDUCATION_TYPE', 'NAME_FAMILY_STATUS', 'NAME_HOUSING_TYPE', \
               'OCCUPATION_TYPE', 'WEEKDAY_APPR_PROCESS_START', 'ORGANIZATION_TYPE', 'WALLSMATERIAL_MODE', \
               'HOUSETYPE_MODE', 'EMERGENCYSTATE_MODE', 'FONDKAPREMONT_MODE']
data = pd.get_dummies(data, columns=categorical)
print(data.shape)
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data, Y, train_size=0.7, random_state=0)
X_train = np.array(X_train)
X_test = np.array(X_test)
y_test = np.array(y_test)
y_train = np.array(y_train)
# Out:
# (215257, 50) (215257, 16)
# (215257, 190)

# %%
import seaborn as sns
import time
# %config InlineBackend.figure_format = 'svg'
import matplotlib.pyplot as plt
from sklearn.metrics import roc_auc_score
from sklearn.metrics import auc, precision_recall_curve, roc_auc_score, roc_curve
from lightgbm import LGBMClassifier
import warnings
warnings.filterwarnings('ignore')
warnings.simplefilter('ignore')
ind = 0
tmp = pd.DataFrame(columns=["learning_rate", "n_estimators", "pr"])
for i in [0.001, 0.01, 0.05, 0.1, 0.5, 1, 2]:
  for j in [20, 30, 50, 100, 300, 1000, 1500]:
    start = time.time()
    clf = LGBMClassifier(max_depth=3, learning_rate=i, n_estimators=j, verbose=-1)
    clf.fit(X_train, y_train)
    precision, recall, thresholds = precision_recall_curve(y_test, clf.predict_proba(X_test)[:, 1])
    pr = auc(recall, precision)
    print(ind, 'Глубина 3, темп обучения', i, 'количество деревьев', j, '-> время', time.time() - start)
    new_line = [i, j, pr]
    tmp.loc[ind] = new_line
    ind += 1
fig, ax = plt.subplots(figsize=(20,10))
a = sns.heatmap(tmp.pivot(index='learning_rate', columns='n_estimators', values='pr'), annot=True, fmt=".3f", vmax=0.245, cmap='BuPu', ax=ax)
plt.xlabel("число итераций бустинга (количество деревьев)")
plt.ylabel("темп (скорость) обучения")
plt.title("Зависимость PR-AUC для LightGBM при глубине деревьев 3 от других параметров")
# Out:
# 0 Глубина 3, темп обучения 0.001 количество деревьев 20 -> время 2.6243038177490234
# 1 Глубина 3, темп обучения 0.001 количество деревьев 30 -> время 2.9136688709259033
# 2 Глубина 3, темп обучения 0.001 количество деревьев 50 -> время 4.031171798706055
# 3 Глубина 3, темп обучения 0.001 количество деревьев 100 -> время 5.225587844848633
# 4 Глубина 3, темп обучения 0.001 количество деревьев 300 -> время 10.581536769866943
# 5 Глубина 3, темп обучения 0.001 количество деревьев 1000 -> время 30.626485109329224
# 6 Глубина 3, темп обучения 0.001 количество деревьев 1500 -> время 46.06449556350708
# 7 Глубина 3, темп обучения 0.01 количество деревьев 20 -> время 2.7671892642974854
# 8 Глубина 3, темп обучения 0.01 количество деревьев 30 -> время 2.890887975692749
# 9 Глубина 3, темп обучения 0.01 количество деревьев 50 -> время 4.742138862609863
# 10 Глубина 3, темп обучения 0.01 количество деревьев 100 -> время 4.6055006980896
# ...

# %%
plt.show()

# %%
import seaborn as sns
import time
# %config InlineBackend.figure_format = 'svg'
import matplotlib.pyplot as plt
from sklearn.metrics import roc_auc_score
from sklearn.metrics import auc, precision_recall_curve, roc_auc_score, roc_curve
from lightgbm import LGBMClassifier
import warnings
warnings.filterwarnings('ignore')
warnings.simplefilter('ignore')
ind = 0
tmp = pd.DataFrame(columns=["learning_rate", "n_estimators", "pr"])
for i in [0.001, 0.01, 0.05, 0.1, 0.5, 1, 2]:
  for j in [20, 30, 50, 100, 300, 1000, 1500]:
    start = time.time()
    clf = LGBMClassifier(max_depth=4, learning_rate=i, n_estimators=j, verbose=-1)
    clf.fit(X_train, y_train)
    precision, recall, thresholds = precision_recall_curve(y_test, clf.predict_proba(X_test)[:, 1])
    pr = auc(recall, precision)
    print(ind, 'Глубина 4, темп обучения', i, 'количество деревьев', j, '-> время', time.time() - start)
    new_line = [i, j, pr]
    tmp.loc[ind] = new_line
    ind += 1
fig, ax = plt.subplots(figsize=(20,10))
a = sns.heatmap(tmp.pivot(index='learning_rate', columns='n_estimators', values='pr'), annot=True, fmt=".3f", vmax=0.245, cmap='BuPu', ax=ax)
plt.xlabel("число итераций бустинга (количество деревьев)")
plt.ylabel("темп (скорость) обучения")
plt.title("Зависимость PR-AUC для LightGBM при глубине деревьев 4 от других параметров")
# Out:
# 0 Глубина 4, темп обучения 0.001 количество деревьев 20 -> время 3.0031332969665527
# 1 Глубина 4, темп обучения 0.001 количество деревьев 30 -> время 3.2428717613220215
# 2 Глубина 4, темп обучения 0.001 количество деревьев 50 -> время 4.785503387451172
# 3 Глубина 4, темп обучения 0.001 количество деревьев 100 -> время 5.788834571838379
# 4 Глубина 4, темп обучения 0.001 количество деревьев 300 -> время 13.033257961273193
# 5 Глубина 4, темп обучения 0.001 количество деревьев 1000 -> время 40.05616545677185
# 6 Глубина 4, темп обучения 0.001 количество деревьев 1500 -> время 58.51043248176575
# 7 Глубина 4, темп обучения 0.01 количество деревьев 20 -> время 2.9834439754486084
# 8 Глубина 4, темп обучения 0.01 количество деревьев 30 -> время 3.234135150909424
# 9 Глубина 4, темп обучения 0.01 количество деревьев 50 -> время 4.359184265136719
# 10 Глубина 4, темп обучения 0.01 количество деревьев 100 -> время 6.303712606430054
# ...

# %%
plt.show()

# %%
import seaborn as sns
import time
# %config InlineBackend.figure_format = 'svg'
import matplotlib.pyplot as plt
from sklearn.metrics import roc_auc_score
from sklearn.metrics import auc, precision_recall_curve, roc_auc_score, roc_curve
from lightgbm import LGBMClassifier
import warnings
warnings.filterwarnings('ignore')
warnings.simplefilter('ignore')
ind = 0
tmp = pd.DataFrame(columns=["learning_rate", "n_estimators", "pr"])
for i in [0.001, 0.01, 0.05, 0.1, 0.5, 1, 2]:
  for j in [20, 30, 50, 100, 300, 1000, 1500]:
    start = time.time()
    clf = LGBMClassifier(max_depth=5, learning_rate=i, n_estimators=j, verbose=-1)
    clf.fit(X_train, y_train)
    precision, recall, thresholds = precision_recall_curve(y_test, clf.predict_proba(X_test)[:, 1])
    pr = auc(recall, precision)
    print(ind, 'Глубина 5, темп обучения', i, 'количество деревьев', j, '-> время', time.time() - start)
    new_line = [i, j, pr]
    tmp.loc[ind] = new_line
    ind += 1
fig, ax = plt.subplots(figsize=(20,10))
a = sns.heatmap(tmp.pivot(index='learning_rate', columns='n_estimators', values='pr'), annot=True, fmt=".3f", vmax=0.245, cmap='BuPu', ax=ax)
plt.xlabel("число итераций бустинга (количество деревьев)")
plt.ylabel("темп (скорость) обучения")
plt.title("Зависимость PR-AUC для LightGBM при глубине деревьев 5 от других параметров")
# Out:
# 0 Глубина 5, темп обучения 0.001 количество деревьев 20 -> время 3.0610461235046387
# 1 Глубина 5, темп обучения 0.001 количество деревьев 30 -> время 3.330019474029541
# 2 Глубина 5, темп обучения 0.001 количество деревьев 50 -> время 4.675479173660278
# 3 Глубина 5, темп обучения 0.001 количество деревьев 100 -> время 6.263599157333374
# 4 Глубина 5, темп обучения 0.001 количество деревьев 300 -> время 14.579060792922974
# 5 Глубина 5, темп обучения 0.001 количество деревьев 1000 -> время 47.2593674659729
# 6 Глубина 5, темп обучения 0.001 количество деревьев 1500 -> время 70.74783849716187
# 7 Глубина 5, темп обучения 0.01 количество деревьев 20 -> время 2.964120864868164
# 8 Глубина 5, темп обучения 0.01 количество деревьев 30 -> время 4.537170171737671
# 9 Глубина 5, темп обучения 0.01 количество деревьев 50 -> время 3.9574227333068848
# 10 Глубина 5, темп обучения 0.01 количество деревьев 100 -> время 6.113312005996704
# ...

# %%
plt.show()

# %%
import seaborn as sns
import time
# %config InlineBackend.figure_format = 'svg'
import matplotlib.pyplot as plt
from sklearn.metrics import roc_auc_score
from sklearn.metrics import auc, precision_recall_curve, roc_auc_score, roc_curve
from lightgbm import LGBMClassifier
import warnings
warnings.filterwarnings('ignore')
warnings.simplefilter('ignore')
ind = 0
tmp = pd.DataFrame(columns=["learning_rate", "n_estimators", "pr"])
for i in [0.001, 0.01, 0.05, 0.1, 0.5, 1, 2]:
  for j in [20, 30, 50, 100, 300, 1000, 1500]:
    start = time.time()
    clf = LGBMClassifier(max_depth=6, learning_rate=i, n_estimators=j, verbose=-1)
    clf.fit(X_train, y_train)
    precision, recall, thresholds = precision_recall_curve(y_test, clf.predict_proba(X_test)[:, 1])
    pr = auc(recall, precision)
    print(ind, 'Глубина 6, темп обучения', i, 'количество деревьев', j, '-> время', time.time() - start)
    new_line = [i, j, pr]
    tmp.loc[ind] = new_line
    ind += 1
fig, ax = plt.subplots(figsize=(20,10))
a = sns.heatmap(tmp.pivot(index='learning_rate', columns='n_estimators', values='pr'), annot=True, fmt=".3f", vmax=0.245, cmap='BuPu', ax=ax)
plt.xlabel("число итераций бустинга (количество деревьев)")
plt.ylabel("темп (скорость) обучения")
plt.title("Зависимость PR-AUC для LightGBM при глубине деревьев 6 от других параметров")
# Out:
# 0 Глубина 6, темп обучения 0.001 количество деревьев 20 -> время 3.0456430912017822
# 1 Глубина 6, темп обучения 0.001 количество деревьев 30 -> время 3.481849431991577
# 2 Глубина 6, темп обучения 0.001 количество деревьев 50 -> время 5.696939706802368
# 3 Глубина 6, темп обучения 0.001 количество деревьев 100 -> время 6.168975830078125
# 4 Глубина 6, темп обучения 0.001 количество деревьев 300 -> время 15.621350288391113
# 5 Глубина 6, темп обучения 0.001 количество деревьев 1000 -> время 51.47101140022278
# 6 Глубина 6, темп обучения 0.001 количество деревьев 1500 -> время 92.63213086128235
# 7 Глубина 6, темп обучения 0.01 количество деревьев 20 -> время 3.8803772926330566
# 8 Глубина 6, темп обучения 0.01 количество деревьев 30 -> время 3.993941068649292
# 9 Глубина 6, темп обучения 0.01 количество деревьев 50 -> время 4.331947088241577
# 10 Глубина 6, темп обучения 0.01 количество деревьев 100 -> время 8.125619173049927
# ...

# %%
plt.show()

# %%
import seaborn as sns
import time
# %config InlineBackend.figure_format = 'svg'
import matplotlib.pyplot as plt
from sklearn.metrics import roc_auc_score
from sklearn.metrics import auc, precision_recall_curve, roc_auc_score, roc_curve
from lightgbm import LGBMClassifier
import warnings
warnings.filterwarnings('ignore')
warnings.simplefilter('ignore')
ind = 0
tmp = pd.DataFrame(columns=["learning_rate", "n_estimators", "pr"])
for i in [0.001, 0.01, 0.05, 0.1, 0.5, 1, 2]:
  for j in [20, 30, 50, 100, 300, 1000, 1500]:
    start = time.time()
    clf = LGBMClassifier(max_depth=7, learning_rate=i, n_estimators=j, verbose=-1)
    clf.fit(X_train, y_train)
    precision, recall, thresholds = precision_recall_curve(y_test, clf.predict_proba(X_test)[:, 1])
    pr = auc(recall, precision)
    print(ind, 'Глубина 7, темп обучения', i, 'количество деревьев', j, '-> время', time.time() - start)
    new_line = [i, j, pr]
    tmp.loc[ind] = new_line
    ind += 1
fig, ax = plt.subplots(figsize=(20,10))
a = sns.heatmap(tmp.pivot(index='learning_rate', columns='n_estimators', values='pr'), annot=True, fmt=".3f", vmax=0.245, cmap='BuPu', ax=ax)
plt.xlabel("число итераций бустинга (количество деревьев)")
plt.ylabel("темп (скорость) обучения")
plt.title("Зависимость PR-AUC для LightGBM при глубине деревьев 7 от других параметров")
# Out:
# 0 Глубина 7, темп обучения 0.001 количество деревьев 20 -> время 4.490903377532959
# 1 Глубина 7, темп обучения 0.001 количество деревьев 30 -> время 3.5775904655456543
# 2 Глубина 7, темп обучения 0.001 количество деревьев 50 -> время 4.255698919296265
# 3 Глубина 7, темп обучения 0.001 количество деревьев 100 -> время 8.160547733306885
# 4 Глубина 7, темп обучения 0.001 количество деревьев 300 -> время 16.62175464630127
# 5 Глубина 7, темп обучения 0.001 количество деревьев 1000 -> время 55.385677337646484
# 6 Глубина 7, темп обучения 0.001 количество деревьев 1500 -> время 80.49956321716309
# 7 Глубина 7, темп обучения 0.01 количество деревьев 20 -> время 4.355532884597778
# 8 Глубина 7, темп обучения 0.01 количество деревьев 30 -> время 3.445187568664551
# 9 Глубина 7, темп обучения 0.01 количество деревьев 50 -> время 4.300390243530273
# 10 Глубина 7, темп обучения 0.01 количество деревьев 100 -> время 8.30410647392273
# ...

# %%
plt.show()

# %%
#CatBoost
data = pd.concat([data_copy, data_cat], axis=1)
categorical = ['NAME_CONTRACT_TYPE', 'CODE_GENDER', 'FLAG_OWN_CAR', 'FLAG_OWN_REALTY', 'NAME_TYPE_SUITE', \
               'NAME_INCOME_TYPE', 'NAME_EDUCATION_TYPE', 'NAME_FAMILY_STATUS', 'NAME_HOUSING_TYPE', \
               'OCCUPATION_TYPE', 'WEEKDAY_APPR_PROCESS_START', 'ORGANIZATION_TYPE', 'WALLSMATERIAL_MODE', \
               'HOUSETYPE_MODE', 'EMERGENCYSTATE_MODE', 'FONDKAPREMONT_MODE']
X_train, X_test, y_train, y_test = train_test_split(data, Y, train_size=0.7, random_state=0)

# %%
import seaborn as sns
# %config InlineBackend.figure_format = 'svg'
import matplotlib.pyplot as plt
from sklearn.metrics import roc_auc_score
from sklearn.metrics import auc, precision_recall_curve, roc_auc_score, roc_curve
from catboost import CatBoostClassifier
import warnings
warnings.filterwarnings('ignore')
warnings.simplefilter('ignore')
ind = 0
tmp = pd.DataFrame(columns=["learning_rate", "iterations", "pr"])
for i in [0.001, 0.01, 0.05, 0.1, 0.5, 1, 2]:
  for j in [20, 30, 50, 100, 300, 1000, 1500]:
    start = time.time()
    clf = CatBoostClassifier(logging_level='Silent', depth=3, learning_rate=i, iterations=j, cat_features=categorical)
    clf.fit(X_train, y_train)
    precision, recall, thresholds = precision_recall_curve(y_test, clf.predict_proba(X_test)[:, 1])
    print(ind, 'Глубина 3, темп обучения', i, 'количество деревьев', j, '-> время', time.time() - start)
    new_line = [i, j, auc(recall, precision)]
    tmp.loc[ind] = new_line
    ind += 1
fig, ax = plt.subplots(figsize=(20,10))
a = sns.heatmap(tmp.pivot(index='learning_rate', columns='iterations', values='pr'), annot=True, fmt=".3f", vmax=0.245, cmap='BuPu', ax=ax)
plt.xlabel("число итераций бустинга (количество деревьев)")
plt.ylabel("темп (скорость) обучения")
plt.title("Зависимость PR-AUC для CatBoost при глубине деревьев 3 от других параметров")
# Out:
# 0 Глубина 3, темп обучения 0.001 количество деревьев 20 -> время 4.08919882774353
# 1 Глубина 3, темп обучения 0.001 количество деревьев 30 -> время 7.132559299468994
# 2 Глубина 3, темп обучения 0.001 количество деревьев 50 -> время 7.478699207305908
# 3 Глубина 3, темп обучения 0.001 количество деревьев 100 -> время 15.672693014144897
# 4 Глубина 3, темп обучения 0.001 количество деревьев 300 -> время 74.1190869808197
# 5 Глубина 3, темп обучения 0.001 количество деревьев 1000 -> время 238.84235739707947
# 6 Глубина 3, темп обучения 0.001 количество деревьев 1500 -> время 346.62974762916565
# 7 Глубина 3, темп обучения 0.01 количество деревьев 20 -> время 5.082427978515625
# 8 Глубина 3, темп обучения 0.01 количество деревьев 30 -> время 4.910027027130127
# 9 Глубина 3, темп обучения 0.01 количество деревьев 50 -> время 9.329139232635498
# 10 Глубина 3, темп обучения 0.01 количество деревьев 100 -> время 15.178231716156006
# ...

# %%
plt.show()

# %%
import seaborn as sns
import time
# %config InlineBackend.figure_format = 'svg'
import matplotlib.pyplot as plt
from sklearn.metrics import roc_auc_score
from sklearn.metrics import auc, precision_recall_curve, roc_auc_score, roc_curve
from catboost import CatBoostClassifier
import warnings
warnings.filterwarnings('ignore')
warnings.simplefilter('ignore')
ind = 0
tmp = pd.DataFrame(columns=["learning_rate", "iterations", "pr"])
for i in [0.001, 0.01, 0.05, 0.1, 0.5, 1, 2]:
  for j in [20, 30, 50, 100, 300, 1000, 1500]:
    start = time.time()
    clf = CatBoostClassifier(logging_level='Silent', depth=4, learning_rate=i, iterations=j, cat_features=categorical)
    clf.fit(X_train, y_train)
    precision, recall, thresholds = precision_recall_curve(y_test, clf.predict_proba(X_test)[:, 1])
    print(ind, 'Глубина 4, темп обучения', i, 'количество деревьев', j, '-> время', time.time() - start)
    new_line = [i, j, auc(recall, precision)]
    tmp.loc[ind] = new_line
    ind += 1
fig, ax = plt.subplots(figsize=(20,10))
a = sns.heatmap(tmp.pivot(index='learning_rate', columns='iterations', values='pr'), annot=True, fmt=".3f", vmax=0.245, cmap='BuPu', ax=ax)
plt.xlabel("число итераций бустинга (количество деревьев)")
plt.ylabel("темп (скорость) обучения")
plt.title("Зависимость PR-AUC для CatBoost при глубине деревьев 4 от других параметров")
# Out:
# 0 Глубина 4, темп обучения 0.001 количество деревьев 20 -> время 10.369245052337646
# 1 Глубина 4, темп обучения 0.001 количество деревьев 30 -> время 5.417047023773193
# 2 Глубина 4, темп обучения 0.001 количество деревьев 50 -> время 9.705390214920044
# 3 Глубина 4, темп обучения 0.001 количество деревьев 100 -> время 16.21515154838562
# 4 Глубина 4, темп обучения 0.001 количество деревьев 300 -> время 92.16547441482544
# 5 Глубина 4, темп обучения 0.001 количество деревьев 1000 -> время 297.1582272052765
# 6 Глубина 4, темп обучения 0.001 количество деревьев 1500 -> время 432.203515291214
# 7 Глубина 4, темп обучения 0.01 количество деревьев 20 -> время 4.861134767532349
# 8 Глубина 4, темп обучения 0.01 количество деревьев 30 -> время 6.211296796798706
# 9 Глубина 4, темп обучения 0.01 количество деревьев 50 -> время 9.080025672912598
# 10 Глубина 4, темп обучения 0.01 количество деревьев 100 -> время 19.00641107559204
# ...

# %%
plt.show()

# %%
import seaborn as sns
# %config InlineBackend.figure_format = 'svg'
import matplotlib.pyplot as plt
from sklearn.metrics import roc_auc_score
from sklearn.metrics import auc, precision_recall_curve, roc_auc_score, roc_curve
from catboost import CatBoostClassifier
import warnings
warnings.filterwarnings('ignore')
warnings.simplefilter('ignore')
ind = 0
tmp = pd.DataFrame(columns=["learning_rate", "iterations", "pr"])
for i in [0.001, 0.01, 0.05, 0.1, 0.5, 1, 2]:
  for j in [20, 30, 50, 100, 300, 1000, 1500]:
    start = time.time()
    clf = CatBoostClassifier(logging_level='Silent', depth=5, learning_rate=i, iterations=j, cat_features=categorical)
    clf.fit(X_train, y_train)
    precision, recall, thresholds = precision_recall_curve(y_test, clf.predict_proba(X_test)[:, 1])
    print(ind, 'Глубина 5, темп обучения', i, 'количество деревьев', j, '-> время', time.time() - start)
    new_line = [i, j, auc(recall, precision)]
    tmp.loc[ind] = new_line
    ind += 1
fig, ax = plt.subplots(figsize=(20,10))
a = sns.heatmap(tmp.pivot(index='learning_rate', columns='iterations', values='pr'), annot=True, fmt=".3f", vmax=0.245, cmap='BuPu', ax=ax)
plt.xlabel("число итераций бустинга (количество деревьев)")
plt.ylabel("темп (скорость) обучения")
plt.title("Зависимость PR-AUC для CatBoost при глубине деревьев 5 от других параметров")
# Out:
# 0 Глубина 5, темп обучения 0.001 количество деревьев 20 -> время 7.149294376373291
# 1 Глубина 5, темп обучения 0.001 количество деревьев 30 -> время 5.847594976425171
# 2 Глубина 5, темп обучения 0.001 количество деревьев 50 -> время 10.815371990203857
# 3 Глубина 5, темп обучения 0.001 количество деревьев 100 -> время 18.178740978240967
# 4 Глубина 5, темп обучения 0.001 количество деревьев 300 -> время 111.99501991271973
# 5 Глубина 5, темп обучения 0.001 количество деревьев 1000 -> время 341.86480712890625
# 6 Глубина 5, темп обучения 0.001 количество деревьев 1500 -> время 512.0824971199036
# 7 Глубина 5, темп обучения 0.01 количество деревьев 20 -> время 5.374160289764404
# 8 Глубина 5, темп обучения 0.01 количество деревьев 30 -> время 6.656213045120239
# 9 Глубина 5, темп обучения 0.01 количество деревьев 50 -> время 10.814791440963745
# 10 Глубина 5, темп обучения 0.01 количество деревьев 100 -> время 18.37190818786621
# ...

# %%
plt.show()

# %%
import seaborn as sns
# %config InlineBackend.figure_format = 'svg'
import matplotlib.pyplot as plt
from sklearn.metrics import roc_auc_score
from sklearn.metrics import auc, precision_recall_curve, roc_auc_score, roc_curve
from catboost import CatBoostClassifier
import warnings
warnings.filterwarnings('ignore')
warnings.simplefilter('ignore')
ind = 0
tmp = pd.DataFrame(columns=["learning_rate", "iterations", "pr"])
for i in [0.001, 0.01, 0.05, 0.1, 0.5, 1, 2]:
  for j in [20, 30, 50, 100, 300, 1000, 1500]:
    start = time.time()
    clf = CatBoostClassifier(logging_level='Silent', depth=6, learning_rate=i, iterations=j, cat_features=categorical)
    clf.fit(X_train, y_train)
    precision, recall, thresholds = precision_recall_curve(y_test, clf.predict_proba(X_test)[:, 1])
    print(ind, 'Глубина 6, темп обучения', i, 'количество деревьев', j, '-> время', time.time() - start)
    new_line = [i, j, auc(recall, precision)]
    tmp.loc[ind] = new_line
    ind += 1
fig, ax = plt.subplots(figsize=(20,10))
a = sns.heatmap(tmp.pivot(index='learning_rate', columns='iterations', values='pr'), annot=True, fmt=".3f", vmax=0.245, cmap='BuPu', ax=ax)
plt.xlabel("число итераций бустинга (количество деревьев)")
plt.ylabel("темп (скорость) обучения")
plt.title("Зависимость PR-AUC для CatBoost при глубине деревьев 6 от других параметров")
# Out:
# 0 Глубина 6, темп обучения 0.001 количество деревьев 20 -> время 6.826937675476074
# 1 Глубина 6, темп обучения 0.001 количество деревьев 30 -> время 6.5263261795043945
# 2 Глубина 6, темп обучения 0.001 количество деревьев 50 -> время 11.987091064453125
# 3 Глубина 6, темп обучения 0.001 количество деревьев 100 -> время 20.77111268043518
# 4 Глубина 6, темп обучения 0.001 количество деревьев 300 -> время 122.5143175125122
# 5 Глубина 6, темп обучения 0.001 количество деревьев 1000 -> время 390.77966475486755
# 6 Глубина 6, темп обучения 0.001 количество деревьев 1500 -> время 591.4623703956604
# 7 Глубина 6, темп обучения 0.01 количество деревьев 20 -> время 4.83734130859375
# 8 Глубина 6, темп обучения 0.01 количество деревьев 30 -> время 8.489975452423096
# 9 Глубина 6, темп обучения 0.01 количество деревьев 50 -> время 11.970036268234253
# 10 Глубина 6, темп обучения 0.01 количество деревьев 100 -> время 20.566718101501465
# ...

# %%
plt.show()

# %%
import seaborn as sns
# %config InlineBackend.figure_format = 'svg'
import matplotlib.pyplot as plt
from sklearn.metrics import roc_auc_score
from sklearn.metrics import auc, precision_recall_curve, roc_auc_score, roc_curve
from catboost import CatBoostClassifier
import warnings
warnings.filterwarnings('ignore')
warnings.simplefilter('ignore')
ind = 0
tmp = pd.DataFrame(columns=["learning_rate", "iterations", "pr"])
for i in [0.001, 0.01, 0.05, 0.1, 0.5, 1, 2]:
  for j in [20, 30, 50, 100, 300, 1000, 1500]:
    start = time.time()
    clf = CatBoostClassifier(logging_level='Silent', depth=7, learning_rate=i, iterations=j, cat_features=categorical)
    clf.fit(X_train, y_train)
    precision, recall, thresholds = precision_recall_curve(y_test, clf.predict_proba(X_test)[:, 1])
    print(ind, 'Глубина 7, темп обучения', i, 'количество деревьев', j, '-> время', time.time() - start)
    new_line = [i, j, auc(recall, precision)]
    tmp.loc[ind] = new_line
    ind += 1
fig, ax = plt.subplots(figsize=(20,10))
a = sns.heatmap(tmp.pivot(index='learning_rate', columns='iterations', values='pr'), annot=True, fmt=".3f", vmax=0.245, cmap='BuPu', ax=ax)
plt.xlabel("число итераций бустинга (количество деревьев)")
plt.ylabel("темп (скорость) обучения")
plt.title("Зависимость PR-AUC для CatBoost при глубине деревьев 7 от других параметров")
# Out:
# 0 Глубина 7, темп обучения 0.001 количество деревьев 20 -> время 6.76226282119751
# 1 Глубина 7, темп обучения 0.001 количество деревьев 30 -> время 8.002836227416992
# 2 Глубина 7, темп обучения 0.001 количество деревьев 50 -> время 12.688402891159058
# 3 Глубина 7, темп обучения 0.001 количество деревьев 100 -> время 25.4075665473938
# 4 Глубина 7, темп обучения 0.001 количество деревьев 300 -> время 134.16705179214478
# 5 Глубина 7, темп обучения 0.001 количество деревьев 1000 -> время 453.1588439941406
# 6 Глубина 7, темп обучения 0.001 количество деревьев 1500 -> время 692.5767705440521
# 7 Глубина 7, темп обучения 0.01 количество деревьев 20 -> время 7.300782680511475
# 8 Глубина 7, темп обучения 0.01 количество деревьев 30 -> время 7.470669507980347
# 9 Глубина 7, темп обучения 0.01 количество деревьев 50 -> время 13.370810985565186
# 10 Глубина 7, темп обучения 0.01 количество деревьев 100 -> время 25.548365354537964
# ...

# %%
plt.show()

# %% [markdown]
# LightGBM показал качество 0.247 при глубине 3, темпе обучения 0.05, количестве деревьев 1000, CatBoost показал аналогичное качество 0.246 при любой глубине из 3-7, темпе обучения 0.01-0.05, количестве деревьев 1000-1500. Таким образом, оба алгоритма могут дать примерно одинаковое качество при подборе наилучших параметров, что согласуется с моими ожиданиями.

# %% [markdown]
# **Бонус (0.2 балла)**
#
# Ваш любимый новогодний фильм/сериал/мультик/книга/музыка/развление/ч-т-о-у-г-о-д-н-о
#
# Всем мандаринок!&#127818;

# %% [markdown]
# Каждое 31 декабря мы с семьёй едем на дачу, где отмечаем Новый год, катаемся на лыжах, коньках, отдыхаем (правда, последние годы, когда у меня идёт в это время процессс подготовки к сессии, отдыхать так беззаботно и долго, как раньше, не получается).
